# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ref = np.load("reference.npz") # Load reference spike train
cur = np.load("my_first_spiketrain.npz") # Load comparison output 
# Note for this to work you have to uncomment the line which fixes the random seed in bush_cell.py
# Also note that we changed the output format to integer for unit indices and float for time indices...

# %%
ref.files
# Out:
# ['arr_0']

# %%
plt.scatter(ref["arr_0"][0],ref["arr_0"][1])
plt.scatter(cur["times"],cur["units"], alpha=0.4)

# the points should overlal

# %%
len(cur["times"])
# Out:
# 618

# %%
len(cur["units"])
# Out:
# 618
